# %%
# !pip install -q requests

# %%
import requests
import json

# %%
url = 'https://www.fandango.com'
response = requests.get(url)

# %%
response.ok
# Out:
# True

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html>\n    <head>\n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n        <!-- salt=d-lay-mps-async-1-25-17 -->\n\n        <title>Movie Tickets &amp; Movie Times | Fandango</title>\n\n        <meta name="description" content="Buy movie tickets in advance, find movie times, watch trailers, read movie reviews, and more at Fandango.">\n        \n            <link rel="canonical" href="https://www.fandango.com/">\n        \n        \n            <link rel="alternate" media="only screen and (max-width: 640px)" href="https://mobile.fandango.com/" >\n        \n        \n        <meta name="viewport" content="width=device-width, initial-scale=1, user-scalable=no">\n        <meta name="robots" content="noodp,noydir">\n\n        \n            <link rel="dns-prefetch" href="//images.fandango.com"><link rel="dns-prefetch" href="//ad.doubleclick.net">\n        \n        \n            <link rel="preconnect" href="//images.fandango.
# ...
